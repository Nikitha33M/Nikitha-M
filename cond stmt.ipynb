# %%
name="aishu"
age=21
city="shimogga"
print("my friend name is {}, age is {} and she stay in {}".format (name,age,city))
# Out:
# my friend name is aishu, age is 21 and she stay in shimogga

# %%
temp=int(input("enter the temp in C"))
if (temp>25):
  print ("temp is suitable for crop growth")
else:
    print ("temp is not suitable for crop growth")
# Out:
# enter the temp in C45
# temp is suitable for crop growth

# %%
rainfall=float(input("enter the rainfall in mm"))
if (rainfall>100):
  print ("rainfall is suitable for crop growth")
else:
    print ("rainfall is not suitable for crop growth")
# Out:
# enter the rainfall in mm200
# rainfall is suitable for crop growth

# %%
temp=float(input("enter the temp in C"))
if (temp>25):
  print ("{} is suitable for crop growth".format (temp) )
else:
    print ("{} is not suitable for crop growth".format (temp))
# Out:
# enter the temp in C49
# 49.0 is suitable for crop growth

# %%
a=int(input("enter a number"))
print (a)
print(type (a))
# Out:
# enter a number3
# 3
# <class 'int'>

# %%
a=float(input("enter a number"))
print (a)
print(type (a))
# Out:
# enter a number67
# 67.0
# <class 'float'>

# %%
day="thursday"
if(day=="wednesday"):
  print("color dress")
else:
  print ("uniform")
# Out:
# uniform

# %%
a=10
b=20
if(a>b):
  print ("{} is greater than {}".format (a,b))
else:
  print ("{} is not greater than {}".format (a,b))
# Out:
# 10 is not greater than 20
