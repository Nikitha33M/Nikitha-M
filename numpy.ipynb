# %%
import numpy as np
scores=[10,12,15,100]
print(np.mean(scores))
# Out:
# 34.25

# %%
import numpy as np
cricket_score=[10,12,17,100]
median_score=np.median(cricket_score)
print("median:",(median_score))
# Out:
# median: 14.5

# %%
import numpy as np
quiz_marks=[2,18,17,19]
median_marks=np.median(quiz_marks)
print("median:",median_marks)
# Out:
# median: 17.5

# %%
from statistics import mode
votes=[1,2,2,3,4]
most_common=mode(votes)
print(most_common)
# Out:
# 2

# %%
from statistics import mode
votes=[1,2,3,3,4,5,6,6,7,8,9,9,9,10]
most_common=mode(votes)
print(most_common)
# Out:
# 9

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 40.824829046386306

# %%
import random
#simulate 10 dice rolls
sample=[random.randint(1,6)
for i in range(10)]
print("sample rolls:",sample)
print("sample mean:",sum(sample)/len(sample))
# Out:
# sample rolls: [5, 5, 1, 2, 1, 5, 1, 2, 5, 6]
# sample mean: 3.3

# %%
import random
#simulators(random prediction
for i in range(5):
  prediction=random.choice(["spam", "not spam"])
  print(f"email{i+1}:{prediction}")
# Out:
# email1:not spam
# email2:spam
# email3:spam
# email4:not spam
# email5:not spam
