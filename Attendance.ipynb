# %%
file=open("attendance.text","w")
file.write("nikitha_p \n sarika_p \n omprakash_p \n raghavendra_p")
file.close()
file=open("attendance.text","r")
content=file.read()
print(content)
file.close()
file=open("attendance.text","a")
file.write("\n gagan_a")
file.close()
file=open("attendance.text","r")
content=file.read()
print(content)
file.close()
# Out:
# nikitha_p
#  sarika_p
#  omprakash_p
#  raghavendra_p
# nikitha_p
#  sarika_p
#  omprakash_p
#  raghavendra_p
#  gagan_a

# %%
file=open("expenditure.text","w")
file.write("1-1-26 $400 fuel \n 2-1-26 $30 juice \n 3-1-26 $2000 shopping")
file.close()
file=open("expenditure.text","r")
content=file.read()
print(content)
file.close()
# Out:
# 1-1-26 $400 fuel
#  2-1-26 $30 juice
#  3-1-26 $2000 shopping

# %%
file=open("journal.text","a")
file.write("date:4-1-26 \n it was a good day")
file.close()
file=open("journal.text","r")
content=file.read()
print(content)
file.close()
# Out:
# date:4-1-26
#  it was a good day
