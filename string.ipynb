# %%
word="NIKITHA"
print(word[2])
print(word[4])
# Out:
# K
# T

# %%
word="NIKITHA"
print(word[-7])
print(word[-3])
# Out:
# N
# T

# %%
text="NIKITHA"
print(text[0:4])
# Out:
# NIKI

# %%
name="Achintya"
print(len(name))
# Out:
# 8

# %%
name="kumar raj"
print("kumar raj".upper())
# Out:
# KUMAR RAJ

# %%
name="kumar RAJ"
print("kumar RAJ".lower())
# Out:
# kumar raj

# %%
name="kumar RAJ"
print("kumar RAJ".title())
# Out:
# Kumar Raj

# %%
data="  Aishwarya  "
print(data.strip())
# Out:
# Aishwarya

# %%
data= "  Aishwarya  "
print(data)
# Out:
#   Aishwarya

# %%
data="  Aishwarya"
print(data.lstrip())
# Out:
# Aishwarya

# %%
msg="I like eng"
print(msg.replace("eng", "math"))
# Out:
# I like math

# %%
email="nikigmail.com"
print("@" in email)
# Out:
# False

# %%
sentence="you are very smart"
words=sentence.split()
print(words)
# Out:
# ['you', 'are', 'very', 'smart']

# %%
words=['you', 'are', 'very', 'smart']
print("".join(words))
# Out:
# youareverysmart

# %%
first="how"
second="are"
third="you"
print(first+" "+second+" "+third)
# Out:
# how are you

# %%
text="Nikitha"
print(text.count("h"))
# Out:
# 1
