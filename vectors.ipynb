# %%
import numpy as np
a=np.array([8,7])
b=np.array([2,4])
print(a+b)
# Out:
# [10 11]

# %%
import numpy as np
a=np.array([8,7,3])
b=np.array([2,4,4])
print(a+b)
# Out:
# [10 11  7]

# %%
import numpy as np
X=np.array([
    [2,3],
    [3,4],
    [4,1]
])
print(X)
# Out:
# [[2 3]
#  [3 4]
#  [4 1]]

# %%
np.dot([1,3],[2,1])
# Out:
# np.int64(5)

# %%
scores=[9,7.82,8.5,8.2]
print(np.mean(scores))
# Out:
# 8.379999999999999

# %%
w=4
Ir=0.2
for i in range(3):
  w=w-Ir*2*w
  print(w)
# Out:
# 2.4
# 1.44
# 0.864
